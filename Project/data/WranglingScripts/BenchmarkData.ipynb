# %%
import pandas as pd

# %%
parquet_file = r'/Users/kayleighgreenwood/CMEECoursework/Project/data/iwt_inquirer-50k.parquet'

# %%
df = pd.read_parquet(parquet_file, engine='auto')

# %%
df.drop_duplicates(subset=['country'], keep='first')
# Out:
#             id         search_term  \
# 0       282410         lion animal
# 6      2583596     extreme weather
# 9       288962    elephant african
# 13     2911195               ivory
# 15     3218666    wildlife farming
# ...        ...                 ...
# 47884  3245710        biodiversity
# 50518  3500834        soil erosion
# 51020  3002379      red list index
# 51349  1889845        biodiversity
# 52648  3648649  ecosystem services
#
#                                              url_desktop  \
# 0      https://www.sfgate.com/news/crime/article/Cali...
# 6      https://edmonton.ctvnews.ca/cold-snap-to-last-...
# 9      https://www.independent.co.uk/news/world/europ...
# 13     https://www.australiannews.net/news/268085639/...
# 15     https://www.business-standard.com/article/inte...
# ...                                                  ...
# 47884  http://thelocalne.ws/2021/03/21/column-native-...
# 50518  http://apanews.net/en/news/ghana-press-focuses...
# ...
